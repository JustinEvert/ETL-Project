# %%
import pandas as pd
import numpy as np
import requests

# %%
pages = np.arange(1,264)
data = []
for x in pages:
    query = f"https://api.datos.gob.mx/v1/fonden.reconstruccion/?page={x}"
    response = requests.get(query)
    print(f"Processing page {x} {response.status_code}: {query}")
    json = response.json()
    data.append(json)
# Out:
# Processing page 1 200: https://api.datos.gob.mx/v1/fonden.reconstruccion/?page=1
# Processing page 2 200: https://api.datos.gob.mx/v1/fonden.reconstruccion/?page=2
# Processing page 3 200: https://api.datos.gob.mx/v1/fonden.reconstruccion/?page=3
# Processing page 4 200: https://api.datos.gob.mx/v1/fonden.reconstruccion/?page=4
# Processing page 5 200: https://api.datos.gob.mx/v1/fonden.reconstruccion/?page=5
# Processing page 6 200: https://api.datos.gob.mx/v1/fonden.reconstruccion/?page=6
# Processing page 7 200: https://api.datos.gob.mx/v1/fonden.reconstruccion/?page=7
# Processing page 8 200: https://api.datos.gob.mx/v1/fonden.reconstruccion/?page=8
# Processing page 9 200: https://api.datos.gob.mx/v1/fonden.reconstruccion/?page=9
# Processing page 10 200: https://api.datos.gob.mx/v1/fonden.reconstruccion/?page=10
# Processing page 11 200: https://api.datos.gob.mx/v1/fonden.reconstruccion/?page=11
# ...

# %%
data[0]
# Out:
# {'pagination': {'pageSize': 100, 'page': 1, 'total': 26300},
#  'results': [{'_id': '55aea1380a1d9e01002bd0f5',
#    'cve': '12048',
#    'cve_ent': '12',
#    'nom_ent': 'Guerrero',
#    'cve_mun': '048',
#    'nom_mun': 'Petatlán',
#    'descripcion': 'Sismo Magnitud 7.2 del 18 de abril de 2014 en 43 Municipios y Sismo Magnitud 6.4 del 8 de mayo de 2014 en 21 municipios',
#    'fecha': '2014-04-18T00:00:00.000Z',
#    'evento': 'Sismo',
#    'clave_proyecto': '010100180420140112SEDATU86315',
#    'dependencia': 'SEDATU',
#    'competencia': 'ESTATAL',
#    'estatus_de_aseguramiento': 'Asegurado',
#    'diagnostico': 'Menor',
#    'tipo_de_apoyo': 'Reconstrucción',
#    'accion': 'Construcción de Vivienda en Sitio',
#    'periodo': '120',
#    'origen_recursos': 'ESTADO',
#    'descripcion_contenido': 'NA',
#    'tipo_de_contenido': 'NA',
#    'monto_contenido': '0',
#    'descripcion_mejora': 'NA',
#    'monto_mejora': '0',
#    'distribucionobrasmejoras': 'NA',
# ...

# %%
results = []
for x in data:
    for y in x['results']:
        results.append(y)

# %%
results[0]
# Out:
# {'_id': '55aea1380a1d9e01002bd0f5',
#  'cve': '12048',
#  'cve_ent': '12',
#  'nom_ent': 'Guerrero',
#  'cve_mun': '048',
#  'nom_mun': 'Petatlán',
#  'descripcion': 'Sismo Magnitud 7.2 del 18 de abril de 2014 en 43 Municipios y Sismo Magnitud 6.4 del 8 de mayo de 2014 en 21 municipios',
#  'fecha': '2014-04-18T00:00:00.000Z',
#  'evento': 'Sismo',
#  'clave_proyecto': '010100180420140112SEDATU86315',
#  'dependencia': 'SEDATU',
#  'competencia': 'ESTATAL',
#  'estatus_de_aseguramiento': 'Asegurado',
#  'diagnostico': 'Menor',
#  'tipo_de_apoyo': 'Reconstrucción',
#  'accion': 'Construcción de Vivienda en Sitio',
#  'periodo': '120',
#  'origen_recursos': 'ESTADO',
#  'descripcion_contenido': 'NA',
#  'tipo_de_contenido': 'NA',
#  'monto_contenido': '0',
#  'descripcion_mejora': 'NA',
#  'monto_mejora': '0',
#  'distribucionobrasmejoras': 'NA',
#  'imagen1': '184_021704_1CN50018X1200907',
#  'imagen2': '184_021704_2CN50018X1200907',
#  'imagen3': '184_021704_3CN50018X1200907',
# ...

# %%
id = []
edo = []
mun = []
evt = []
fec = []
apy = []
acc = []

for x in results:
    id.append(x['_id'])
    edo.append(x['nom_ent'])
    mun.append(x['nom_mun'])
    evt.append(x['evento'])
    fec.append(x['fecha'])
    apy.append(x['tipo_de_apoyo'])
    acc.append(x['accion'])

# %%
df1 = pd.DataFrame({
"id": id,
"Estado": edo,
"Municipio": mun,
"Evento": evt,
"Fecha": fec,
"Tipo de Apoyo": apy,
"Accion": acc
})
df1.head()
# Out:
#                          id               Estado  \
# 0  55aea1380a1d9e01002bd0f5             Guerrero
# 1  55aea1380a1d9e01002bd0f6             Guerrero
# 2  55aea1380a1d9e01002bd0f7  Baja California Sur
# 3  55aea1380a1d9e01002bd0f8  Baja California Sur
# 4  55aea1380a1d9e01002bd0f9             Guerrero
#
#                            Municipio   Evento                     Fecha  \
# 0                           Petatlán    Sismo  2014-04-18T00:00:00.000Z
# 1                           Petatlán    Sismo  2014-04-18T00:00:00.000Z
# 2                          Los Cabos  Huracán  2014-09-14T00:00:00.000Z
# 3                          Los Cabos  Huracán  2014-09-14T00:00:00.000Z
# 4  La Unión de Isidoro Montes de Oca    Sismo  2014-04-18T00:00:00.000Z
#
#     Tipo de Apoyo                             Accion
# 0  Reconstrucción  Construcción de Vivienda en Sitio
# 1  Reconstrucción  Construcción de Vivienda en Sitio
# 2  Reconstrucción                       Construcción
# ...

# %%
df1[["Año", "Mes", "Dia"]] = df1["Fecha"].str.split("-", expand = True)
df1.head()
# Out:
#                          id               Estado  \
# 0  55aea1380a1d9e01002bd0f5             Guerrero
# 1  55aea1380a1d9e01002bd0f6             Guerrero
# 2  55aea1380a1d9e01002bd0f7  Baja California Sur
# 3  55aea1380a1d9e01002bd0f8  Baja California Sur
# 4  55aea1380a1d9e01002bd0f9             Guerrero
#
#                            Municipio   Evento                     Fecha  \
# 0                           Petatlán    Sismo  2014-04-18T00:00:00.000Z
# 1                           Petatlán    Sismo  2014-04-18T00:00:00.000Z
# 2                          Los Cabos  Huracán  2014-09-14T00:00:00.000Z
# 3                          Los Cabos  Huracán  2014-09-14T00:00:00.000Z
# 4  La Unión de Isidoro Montes de Oca    Sismo  2014-04-18T00:00:00.000Z
#
#     Tipo de Apoyo                             Accion   Año Mes  \
# 0  Reconstrucción  Construcción de Vivienda en Sitio  2014  04
# 1  Reconstrucción  Construcción de Vivienda en Sitio  2014  04
# ...

# %%
del df1['Dia']

# %%
df1.head()
# Out:
#                          id               Estado  \
# 0  55aea1380a1d9e01002bd0f5             Guerrero
# 1  55aea1380a1d9e01002bd0f6             Guerrero
# 2  55aea1380a1d9e01002bd0f7  Baja California Sur
# 3  55aea1380a1d9e01002bd0f8  Baja California Sur
# 4  55aea1380a1d9e01002bd0f9             Guerrero
#
#                            Municipio   Evento                     Fecha  \
# 0                           Petatlán    Sismo  2014-04-18T00:00:00.000Z
# 1                           Petatlán    Sismo  2014-04-18T00:00:00.000Z
# 2                          Los Cabos  Huracán  2014-09-14T00:00:00.000Z
# 3                          Los Cabos  Huracán  2014-09-14T00:00:00.000Z
# 4  La Unión de Isidoro Montes de Oca    Sismo  2014-04-18T00:00:00.000Z
#
#     Tipo de Apoyo                             Accion   Año Mes
# 0  Reconstrucción  Construcción de Vivienda en Sitio  2014  04
# 1  Reconstrucción  Construcción de Vivienda en Sitio  2014  04
# ...

# %%
del df1['Fecha']
df1.head()
# Out:
#                          id               Estado  \
# 0  55aea1380a1d9e01002bd0f5             Guerrero
# 1  55aea1380a1d9e01002bd0f6             Guerrero
# 2  55aea1380a1d9e01002bd0f7  Baja California Sur
# 3  55aea1380a1d9e01002bd0f8  Baja California Sur
# 4  55aea1380a1d9e01002bd0f9             Guerrero
#
#                            Municipio   Evento   Tipo de Apoyo  \
# 0                           Petatlán    Sismo  Reconstrucción
# 1                           Petatlán    Sismo  Reconstrucción
# 2                          Los Cabos  Huracán  Reconstrucción
# 3                          Los Cabos  Huracán  Reconstrucción
# 4  La Unión de Isidoro Montes de Oca    Sismo  Reconstrucción
#
#                               Accion   Año Mes
# 0  Construcción de Vivienda en Sitio  2014  04
# 1  Construcción de Vivienda en Sitio  2014  04
# 2                       Construcción  2014  09
# 3                       Construcción  2014  09
# 4  Construcción de Vivienda en Sitio  2014  04

# %%
del df1["id"]
df1.head()
# Out:
#                 Estado                          Municipio   Evento  \
# 0             Guerrero                           Petatlán    Sismo
# 1             Guerrero                           Petatlán    Sismo
# 2  Baja California Sur                          Los Cabos  Huracán
# 3  Baja California Sur                          Los Cabos  Huracán
# 4             Guerrero  La Unión de Isidoro Montes de Oca    Sismo
#
#     Tipo de Apoyo                             Accion   Año Mes
# 0  Reconstrucción  Construcción de Vivienda en Sitio  2014  04
# 1  Reconstrucción  Construcción de Vivienda en Sitio  2014  04
# 2  Reconstrucción                       Construcción  2014  09
# 3  Reconstrucción                       Construcción  2014  09
# 4  Reconstrucción  Construcción de Vivienda en Sitio  2014  04

# %%
df1["id"] = np.arange(1,26301)
# Out:
#                 Estado                          Municipio   Evento  \
# 0             Guerrero                           Petatlán    Sismo
# 1             Guerrero                           Petatlán    Sismo
# 2  Baja California Sur                          Los Cabos  Huracán
# 3  Baja California Sur                          Los Cabos  Huracán
# 4             Guerrero  La Unión de Isidoro Montes de Oca    Sismo
#
#     Tipo de Apoyo                             Accion   Año Mes  id
# 0  Reconstrucción  Construcción de Vivienda en Sitio  2014  04   1
# 1  Reconstrucción  Construcción de Vivienda en Sitio  2014  04   2
# 2  Reconstrucción                       Construcción  2014  09   3
# 3  Reconstrucción                       Construcción  2014  09   4
# 4  Reconstrucción  Construcción de Vivienda en Sitio  2014  04   5

# %%
df1 = df1[["id","Estado","Municipio","Evento","Tipo de Apoyo","Accion","Año","Mes"]]
# Out:
#                  Estado                          Municipio   Evento  \
# id
# 1              Guerrero                           Petatlán    Sismo
# 2              Guerrero                           Petatlán    Sismo
# 3   Baja California Sur                          Los Cabos  Huracán
# 4   Baja California Sur                          Los Cabos  Huracán
# 5              Guerrero  La Unión de Isidoro Montes de Oca    Sismo
#
#      Tipo de Apoyo                             Accion   Año Mes
# id
# 1   Reconstrucción  Construcción de Vivienda en Sitio  2014  04
# 2   Reconstrucción  Construcción de Vivienda en Sitio  2014  04
# 3   Reconstrucción                       Construcción  2014  09
# 4   Reconstrucción                       Construcción  2014  09
# 5   Reconstrucción  Construcción de Vivienda en Sitio  2014  04

# %%
df1.rename(columns={"Tipo de Apoyo": "tipo"}, inplace=True)
df1.rename(columns={"Estado": "estado"}, inplace=True)
df1.rename(columns={"Municipio": "municipio"}, inplace=True)
df1.rename(columns={"Evento": "evento"}, inplace=True)
df1.rename(columns={"Accion": "accion"}, inplace=True)
df1.rename(columns={"Año": "año"}, inplace=True)
df1.rename(columns={"Mes": "mes"}, inplace=True)
df1.set_index("id").head()
# Out:
#                  estado                          municipio   evento  \
# id
# 1              Guerrero                           Petatlán    Sismo
# 2              Guerrero                           Petatlán    Sismo
# 3   Baja California Sur                          Los Cabos  Huracán
# 4   Baja California Sur                          Los Cabos  Huracán
# 5              Guerrero  La Unión de Isidoro Montes de Oca    Sismo
#
#               tipo                             accion   año mes
# id
# 1   Reconstrucción  Construcción de Vivienda en Sitio  2014  04
# 2   Reconstrucción  Construcción de Vivienda en Sitio  2014  04
# 3   Reconstrucción                       Construcción  2014  09
# 4   Reconstrucción                       Construcción  2014  09
# 5   Reconstrucción  Construcción de Vivienda en Sitio  2014  04

# %%
df1["estado"].value_counts()
# Out:
# Guerrero                           8083
# Baja California Sur                7183
# Chiapas                            7174
# Veracruz de Ignacio de la Llave    1015
# Durango                             945
# Chihuahua                           497
# Sonora                              458
# Campeche                            316
# Tamaulipas                          219
# Quintana Roo                        158
# Oaxaca                              121
# Baja California                      61
# México                               30
# Colima                               19
# Jalisco                              11
# Sinaloa                              10
# Name: estado, dtype: int64

# %%
df1["evento"].value_counts()
# Out:
# Sismo                   14193
# Huracán                  6984
# Lluvia Severa            2283
# Tormenta Tropical        1335
# Lluvia severa             979
# Inundación Pluvial        497
# Movimiento de Ladera       28
# Inundación Costera          1
# Name: evento, dtype: int64

# %%
from sqlalchemy import create_engine
db_string = "postgres://postgres:pkmn.2012@localhost:5432/ETL_project"
db = create_engine(db_string)

# %%
db.table_names()
# Out:
# ['consolidated', 'fonden']

# %%
df1.to_sql(name='fonden', con=db, if_exists='append', index=False)

# %%
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import inspect, func

# %%
inspector = inspect(db)
columns = inspector.get_columns('consolidated')
for c in columns:
    print(c['name'], c["type"])
# Out:
# id INTEGER
# ano INTEGER
# mes VARCHAR
# estado VARCHAR
# cliente VARCHAR
# modalidad VARCHAR
# acciones DOUBLE PRECISION
# monto DOUBLE PRECISION

# %%
columns = inspector.get_columns('fonden')
for c in columns:
    print(c['name'], c["type"])
# Out:
# id INTEGER
# estado VARCHAR
# municipio VARCHAR
# evento VARCHAR
# tipo VARCHAR
# accion VARCHAR
# año INTEGER
# mes VARCHAR

# %%
session = Session(db)

# %%
from sqlalchemy import MetaData
meta = MetaData()
meta.reflect(bind=db)

# %%
consolidated = meta.tables['consolidated']

# %%
fonden = meta.tables['fonden']

# %%
query1 = session.query(consolidated.columns.estado, func.sum(consolidated.columns.acciones), func.sum(consolidated.columns.monto)).\
group_by(consolidated.columns.estado).all()
query1
# Out:
# [('Chiapas', 130434.0, 39574124828.2199),
#  ('Hidalgo', 252254.0, 109303094147.43),
#  ('San Luis Potosí', 181338.0, 74796865272.5202),
#  ('Baja California', 370364.0, 122067306039.131),
#  ('Veracruz de Ignacio de la Llave', 370738.0, 150386017825.221),
#  ('Aguascalientes', 176245.0, 61049870655.4193),
#  ('Yucatán', 229058.0, 74408798541.3003),
#  ('Colima', 78752.0, 30313682630.36),
#  ('Zacatecas', 2086291.0, 611534480449.452),
#  ('Tamaulipas', 381176.0, 122829766327.07),
#  ('Michoacán de Ocampo', 159514.0, 62131116269.1598),
#  ('Chihuahua', 492003.0, 144881336218.58),
#  ('Ciudad de México', 527583.0, 206789033134.55),
#  ('México', 709473.0, 288905110776.688),
#  ('Tlaxcala', 37137.0, 10873001686.2),
#  ('Durango', 139141.0, 39338549250.3297),
#  ('Baja California Sur', 86462.0, 30746471515.25),
#  ('Sonora', 299180.0, 102093294929.23),
#  ('Jalisco', 721368.0, 256869203395.911),
#  ('Nayarit', 66348.0, 25338826813.4502),
#  ('Guerrero', 89979.0, 35857114261.04),
# ...

# %%
query2 = session.query(fonden.columns.estado, func.count(fonden.columns.evento)).\
group_by(fonden.columns.estado).all()
query2
# Out:
# [('Quintana Roo', 158),
#  ('Sonora', 458),
#  ('Jalisco', 11),
#  ('Guerrero', 8083),
#  ('Oaxaca', 121),
#  ('Chiapas', 7174),
#  ('Baja California', 61),
#  ('Veracruz de Ignacio de la Llave', 1015),
#  ('Colima', 19),
#  ('Tamaulipas', 219),
#  ('Chihuahua', 497),
#  ('México', 30),
#  ('Durango', 945),
#  ('Campeche', 316),
#  ('Baja California Sur', 7183),
#  ('Sinaloa', 10)]

# %%
df2 = pd.DataFrame({
"estado": [x[0] for x in query1],
"acciones": [x[1] for x in query1],
"monto": [x[2] for x in query1]
})

# %%
df3 = pd.DataFrame({
"estado": [x[0] for x in query2],
"desastres": [x[1] for x in query2]
})

# %%
df4 = pd.merge(df2, df3, on="estado")
df4.sort_values(by="acciones", ascending=False)
# Out:
#                              estado  acciones         monto  desastres
# 10                          Jalisco  721368.0  2.568692e+11         11
# 6                            México  709473.0  2.889051e+11         30
# 5                         Chihuahua  492003.0  1.448813e+11        497
# 4                        Tamaulipas  381176.0  1.228298e+11        219
# 2   Veracruz de Ignacio de la Llave  370738.0  1.503860e+11       1015
# 1                   Baja California  370364.0  1.220673e+11         61
# 15                     Quintana Roo  333730.0  1.291585e+11        158
# 9                            Sonora  299180.0  1.020933e+11        458
# 14                          Sinaloa  244109.0  8.773815e+10         10
# 7                           Durango  139141.0  3.933855e+10        945
# 0                           Chiapas  130434.0  3.957412e+10       7174
# 11                         Guerrero   89979.0  3.585711e+10       8083
# ...
